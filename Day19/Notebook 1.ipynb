# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df = spark.read.option("header", "true") \
    .csv("Files/fabric_sales_data.csv")

df.show()
# Out:
# StatementMeta(, d069da10-3c6a-4a36-9166-c40f4d4d825e, 3, Finished, Available, Finished, False)
# +-------+----------+------+-----+----------+
# |OrderID|   Product|Region|Sales|      Date|
# +-------+----------+------+-----+----------+
# |      1|    Laptop| India|50000|2026-04-01|
# |      2|     Phone|   USA|30000|2026-04-02|
# |      3|    Tablet| India|20000|2026-04-03|
# |      4|   Monitor|    UK|15000|2026-04-04|
# |      5|  Keyboard| India| 5000|2026-04-05|
# |      6|     Mouse|   USA| 7000|2026-04-06|
# |      7|   Printer|    UK|12000|2026-04-07|
# |      8|    Camera| India|25000|2026-04-08|
# |      9|Headphones|   USA|18000|2026-04-09|
# |     10|   Speaker|    UK| 9000|2026-04-10|
# +-------+----------+------+-----+----------+

# %%
from pyspark.sql.functions import col

df = df.withColumn("Sales", col("Sales").cast("float"))
df.show()
# Out:
# StatementMeta(, d069da10-3c6a-4a36-9166-c40f4d4d825e, 6, Finished, Available, Finished, False)
# +-------+----------+------+-------+----------+
# |OrderID|   Product|Region|  Sales|      Date|
# +-------+----------+------+-------+----------+
# |      1|    Laptop| India|50000.0|2026-04-01|
# |      2|     Phone|   USA|30000.0|2026-04-02|
# |      3|    Tablet| India|20000.0|2026-04-03|
# |      4|   Monitor|    UK|15000.0|2026-04-04|
# |      5|  Keyboard| India| 5000.0|2026-04-05|
# |      6|     Mouse|   USA| 7000.0|2026-04-06|
# |      7|   Printer|    UK|12000.0|2026-04-07|
# |      8|    Camera| India|25000.0|2026-04-08|
# |      9|Headphones|   USA|18000.0|2026-04-09|
# |     10|   Speaker|    UK| 9000.0|2026-04-10|
# +-------+----------+------+-------+----------+

# %%
df.groupBy("Region").sum("Sales").show()
# Out:
# StatementMeta(, d069da10-3c6a-4a36-9166-c40f4d4d825e, 8, Finished, Available, Finished, False)
# +------+----------+
# |Region|sum(Sales)|
# +------+----------+
# | India|  100000.0|
# |   USA|   55000.0|
# |    UK|   36000.0|
# +------+----------+

# %%
df.write.mode("overwrite").saveAsTable("sales_table")
# Out:
# StatementMeta(, d069da10-3c6a-4a36-9166-c40f4d4d825e, 9, Finished, Available, Finished, False)

# %%
spark.sql("""
SELECT Region, SUM(Sales) AS Total_Sales
FROM sales_table
GROUP BY Region
""").show()
# Out:
# StatementMeta(, d069da10-3c6a-4a36-9166-c40f4d4d825e, 10, Finished, Available, Finished, False)
# +------+-----------+
# |Region|Total_Sales|
# +------+-----------+
# | India|   100000.0|
# |   USA|    55000.0|
# |    UK|    36000.0|
# +------+-----------+
